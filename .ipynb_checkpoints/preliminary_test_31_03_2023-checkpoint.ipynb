# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns
from tqdm.notebook import tqdm
import pickle

from sklearn.linear_model import LinearRegression
from statsmodels.regression.rolling import RollingOLS
import arch

from src.backtesting import *
from src.trading import *
from src.laplacian_estimators import *
from src.preprocessing import *

# %%
def sharpe_ratio(x):
    return x.mean() / x.std() * np.sqrt(12)

def sortino_ratio(x):
    mean = x.mean()
    std_neg = x[x<0].std()
    return mean / std_neg * np.sqrt(12)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Stocks Data

# %%
# SP500 Data
prices = pd.read_csv("./data/sp500_prices_long.csv", parse_dates=['Date'])
prices['month'] = prices['Date'].dt.month
prices['year'] = prices['Date'].dt.year
raw_monthly_prices = prices.groupby(['year', 'month']).last().reset_index()
raw_monthly_prices['year_month'] = raw_monthly_prices['year'].astype(str) + ('00' + raw_monthly_prices['month'].astype(str)).str[-2:]
raw_monthly_prices = raw_monthly_prices.set_index('year_month').drop(columns=['year', 'month', 'Date'])
monthly_prices = raw_monthly_prices.loc[:, raw_monthly_prices.isna().mean(axis=0) < .5]
monthly_log_returns = np.log(monthly_prices).diff().iloc[1:]
monthly_log_returns = np.exp(monthly_log_returns) - 1
monthly_log_returns.head()
# Out:
#              A  AAL  AAP      AAPL       ABC      ABMD       ABT  ACN  \
# year_month
# 199502     NaN  NaN  NaN -0.018981       NaN  0.555556  0.003533  NaN
# 199503     NaN  NaN  NaN -0.107596       NaN -0.171429  0.007043  NaN
# 199504     NaN  NaN  NaN  0.085107       NaN  0.206897  0.107499  NaN
# 199505     NaN  NaN  NaN  0.089615  0.028249 -0.028571  0.015873  NaN
# 199506     NaN  NaN  NaN  0.117294  0.002747  0.014706  0.012500  NaN
#
#                 ADBE       ADI  ...       WST        WY  WYNN       XEL  \
# year_month                      ...
# 199502      0.235421  0.168606  ... -0.037036  0.075907   NaN -0.021621
# 199503      0.385995  0.014925  ... -0.019232 -0.046012   NaN -0.027624
# 199504      0.176768  0.053921  ...  0.102896  0.080386   NaN  0.020997
# 199505     -0.107296  0.158139  ...  0.004465  0.054687   NaN  0.070621
# 199506      0.115385  0.092370  ... -0.004445  0.074074   NaN -0.026385
#
#                  XOM      XRAY  YUM  ZBH      ZBRA      ZION
# year_month
# 199502      0.034362 -0.049999  NaN  NaN -0.090625  0.059603
# 199503      0.043053  0.047373  NaN  NaN  0.127148 -0.048934
# 199504      0.043151  0.014389  NaN  NaN  0.118902  0.129139
# 199505      0.037924  0.021277  NaN  NaN -0.019073  0.061584
# 199506     -0.010507  0.002102  NaN  NaN  0.183333  0.112762
#
# [5 rows x 427 columns]

# %%
# CRSP Data
prices = pd.read_csv("./data/prices_CRSP.csv")
prices['datadate'] = prices['datadate'].astype(str).str[:-2]
prices = prices.rename(columns={'datadate': 'year_month'}).set_index('year_month')
monthly_log_returns = np.log(prices).diff().iloc[1:]
monthly_log_returns = np.exp(monthly_log_returns) - 1
monthly_log_returns.head()
# Out:
#                 1010  1034      1040  1054  1062      1075  1076      1078  \
# year_month
# 196207      0.143729   NaN -0.056180   NaN   NaN  0.087379   NaN -0.003953
# 196208     -0.005335   NaN  0.035714   NaN   NaN  0.026786   NaN -0.079365
# 196209     -0.054231   NaN -0.103448   NaN   NaN -0.026087   NaN  0.038793
# 196210      0.071204   NaN -0.070513   NaN   NaN -0.048929   NaN  0.074689
# 196211      0.071763   NaN  0.158621   NaN   NaN  0.131431   NaN  0.077220
#
#             1119  1128  ...  264647  264686  264708  266214  268208  269005  \
# year_month              ...
# 196207       NaN   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 196208       NaN   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 196209       NaN   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 196210       NaN   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 196211       NaN   NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#             277812  287462  287882  294524
# year_month
# 196207         NaN     NaN     NaN     NaN
# 196208         NaN     NaN     NaN     NaN
# 196209         NaN     NaN     NaN     NaN
# 196210         NaN     NaN     NaN     NaN
# 196211         NaN     NaN     NaN     NaN
#
# [5 rows x 3218 columns]

# %% [markdown]
# ## Load Factors Data

# %%
factors = pd.read_csv("./data/F-F_Research_Data_5_Factors_2x3.csv", skiprows=2)
factors = factors[factors['Date'].astype(str).str.strip().str.len() == 6]
factors = factors.set_index('Date')
factors = factors.astype(np.float64)
factors
# Out:
#         Mkt-RF   SMB   HML   RMW   CMA    RF
# Date
# 196307   -0.39 -0.41 -0.97  0.68 -1.18  0.27
# 196308    5.07 -0.80  1.80  0.36 -0.35  0.25
# 196309   -1.57 -0.52  0.13 -0.71  0.29  0.27
# 196310    2.53 -1.39 -0.10  2.80 -2.01  0.29
# 196311   -0.85 -0.88  1.75 -0.51  2.24  0.27
# ...        ...   ...   ...   ...   ...   ...
# 202205   -0.34 -0.06  8.41  1.44  3.98  0.03
# 202206   -8.43  1.30 -5.97  1.85 -4.70  0.06
# 202207    9.57  1.88 -4.10  0.68 -6.94  0.08
# 202208   -3.78  1.51  0.31 -4.80  1.31  0.19
# 202209   -9.36 -0.96  0.05 -1.40 -0.82  0.19
#
# [711 rows x 6 columns]

# %% [markdown]
# ## Marge Indexes

# %%
idx = monthly_log_returns.merge(factors, right_index=True, left_index=True).index
monthly_log_returns = monthly_log_returns.loc[idx]
factors = factors.loc[idx]

# %% [markdown]
# ## Remove Risk-free Returns

# %%
monthly_log_returns_rf = monthly_log_returns - factors[['RF']].values / 100
factors_rf = factors.drop(columns='RF')

# %% [markdown]
# # Backtest Strategies

# %%
split_window_size = 12
config_backtesters = dict()
trading_rules_dict = ({f'decile-{d}': BuyDecileTradingRule(d) for d in range(1, 11)} |
                      {'q=0.2': QuantilesTradingRule(q=0.2)}
)

# %%
# Identity
config_backtesters['NoPreprocessing Identity'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianIdentityLaplacianEstimator(),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

config_backtesters['Residuals Identity'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianIdentityLaplacianEstimator(),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

# Corr-50
config_backtesters['NoPreprocessing Corr-50'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianCorrKLaplacianEstimator(k=50),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

config_backtesters['Residuals Corr-50'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianCorrKLaplacianEstimator(k=50),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

# %%
# LGMRF
tol = 2.5e-4
config_backtesters['NoPreprocessing LGMRF'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(max_iter=700, tol=tol),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

config_backtesters['NoPreprocessing LGMRF uniform-weighting'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(max_iter=700, weights='uniform', tol=tol),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

config_backtesters['Residuals LGMRF'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(max_iter=700, tol=tol),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

config_backtesters['Residuals LGMRF uniform-weighting'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=SpreadsTrader(
        laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(max_iter=700, weights='uniform', tol=tol),
        trading_rule=trading_rules_dict
    ),
    split_window_size=split_window_size
)

# LTMRF
# config_backtesters['NoPreprocessing LTMRF'] = ConfigBacktester(
#     preprocessor=NoPreprocessing(),
#     trader=SpreadsTrader(laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(distribution='student', max_iter=700)),
#     split_window_size=split_window_size
# )
# 
# config_backtesters['NoPreprocessing LTMRF uniform-weighting'] = ConfigBacktester(
#     preprocessor=NoPreprocessing(),
#     trader=SpreadsTrader(laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(distribution='student', max_iter=700, weights='uniform')),
#     split_window_size=split_window_size
# )
# 
# config_backtesters['Residuals LTMRF'] = ConfigBacktester(
#     preprocessor=ResidualsPreprocessing(factors_rf),
#     trader=SpreadsTrader(laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(distribution='student', max_iter=700)),
#     split_window_size=split_window_size
# )
# 
# config_backtesters['Residuals LTMRF uniform-weighting'] = ConfigBacktester(
#     preprocessor=ResidualsPreprocessing(factors_rf),
#     trader=SpreadsTrader(laplacian_estimator=LaplacianGraphLearningLaplacianEstimator(distribution='student', max_iter=700, weights='uniform')),
#     split_window_size=split_window_size
# )

# %%
# Pairs-5
config_backtesters['NoPreprocessing Pairs-5'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=PairsDistanceTrader(5, trading_rule={'std=2': StdTradingRule()}),
    split_window_size=split_window_size
)

config_backtesters['Residuals Pairs-5'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=PairsDistanceTrader(5, trading_rule={'std=2': StdTradingRule()}),
    split_window_size=split_window_size
)

# Pairs-20

config_backtesters['NoPreprocessing Pairs-20'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=PairsDistanceTrader(20, trading_rule={'std=2': StdTradingRule()}),
    split_window_size=split_window_size
)

config_backtesters['Residuals Pairs-20'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=PairsDistanceTrader(20, trading_rule={'std=2': StdTradingRule()}),
    split_window_size=split_window_size
)

# %%
backtester = GridBacktester(config_backtesters, verbose=True)

# %%
config_returns = backtester.fit_backtest(monthly_log_returns)
config_returns
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 12/12 [4:37:10<00:00, 1385.84s/it]
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\miche\anaconda3\envs\main2023\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# Strategy    NoPreprocessing Identity                                          \
# TradingRule                 decile-1  decile-2  decile-3  decile-4  decile-5
# 196807                      0.018124  0.021893  0.025563  0.009207  0.021511
# 196808                      0.036385  0.047524  0.052825  0.053510  0.038852
# 196809                      0.014603  0.017385  0.009723  0.010030  0.005645
# 196810                      0.068734  0.097077  0.068008  0.081080  0.083451
# 196811                     -0.008520 -0.027185 -0.017177 -0.016304 -0.042182
# ...                              ...       ...       ...       ...       ...
# 202202                      0.014220  0.002839  0.014794  0.006681  0.001937
# 202203                     -0.064034 -0.064539 -0.064967 -0.064214 -0.053519
# 202204                      0.027793  0.015695  0.007754  0.005933  0.010047
# 202205                     -0.083586 -0.079054 -0.090486 -0.054453 -0.059065
# 202206                      0.074709  0.085499  0.090896  0.080591  0.079553
#
# Strategy                                                       ...  \
# TradingRule  decile-6  decile-7  decile-8  decile-9 decile-10  ...
# 196807       0.024649  0.016379  0.029108 -0.013077  0.001829  ...
# 196808       0.031449  0.046399  0.051187  0.044796  0.051317  ...
# 196809       0.000765  0.022044  0.007207 -0.004294 -0.000073  ...
# 196810       0.074424  0.051507  0.050922  0.042783  0.040403  ...
# 196811      -0.032369 -0.031121 -0.061280 -0.031989 -0.049470  ...
# ...               ...       ...       ...       ...       ...  ...
# 202202       0.001321  0.009337  0.022543  0.031379  0.025038  ...
# 202203      -0.071386 -0.062270 -0.064759 -0.049963 -0.052309  ...
# 202204      -0.000624  0.019920  0.012548  0.012199  0.014075  ...
# 202205      -0.079629 -0.084662 -0.093210 -0.080502 -0.077361  ...
# 202206       0.089226  0.063585  0.079245  0.047803  0.024497  ...
#
# Strategy    Residuals LGMRF uniform-weighting                                \
# TradingRule                          decile-6  decile-7  decile-8  decile-9
# 196807                               0.011089  0.007662  0.005964  0.002626
# 196808                               0.030315  0.040275  0.053092  0.061456
# 196809                               0.023442 -0.000375 -0.016119 -0.008731
# 196810                               0.048667  0.068685  0.063648  0.065829
# 196811                              -0.036813 -0.027396 -0.025500 -0.017382
# ...                                       ...       ...       ...       ...
# 202202                               0.012985  0.007115  0.026854  0.006806
# 202203                              -0.062265 -0.059236 -0.059651 -0.062696
# 202204                               0.002553 -0.005316  0.011295 -0.000118
# 202205                              -0.064117 -0.078668 -0.069257 -0.082510
# 202206                               0.083855  0.072935  0.060980  0.052375
#
# Strategy                        NoPreprocessing Pairs-5 Residuals Pairs-5  \
# TradingRule decile-10     q=0.2                   std=2             std=2
# 196807      -0.039921  0.069238                0.052559          0.000000
# 196808       0.033051  0.016330                0.000000          0.043724
# 196809      -0.037247  0.073611               -0.040964         -0.101283
# 196810       0.072797 -0.043149               -0.011610          0.036990
# 196811      -0.015285 -0.046957               -0.065385          0.000000
# ...               ...       ...                     ...               ...
# 202202       0.024285 -0.010425               -0.005236          0.000000
# 202203      -0.073974  0.011569               -0.005858          0.000000
# 202204       0.000129  0.045050                0.000000          0.000608
# 202205      -0.052694 -0.070530               -0.025228          0.000000
# 202206       0.028414  0.057560                0.021607          0.000000
#
# Strategy    NoPreprocessing Pairs-20 Residuals Pairs-20
# TradingRule                    std=2              std=2
# 196807                      0.035396           0.000000
# 196808                      0.000000           0.031184
# 196809                     -0.063309          -0.019355
# 196810                      0.001736           0.023679
# 196811                     -0.003886           0.000000
# ...                              ...                ...
# 202202                      0.016645           0.012089
# 202203                      0.007094           0.000000
# 202204                     -0.007785           0.004928
# 202205                     -0.009610           0.002784
# 202206                      0.033670           0.012416
#
# [648 rows x 92 columns]

# %%
config_returns.index = config_returns.index.astype('str')
config_returns.index.name = 'Date'
config_returns
# Out:
# Strategy    NoPreprocessing Identity                                          \
# TradingRule                 decile-1  decile-2  decile-3  decile-4  decile-5
# Date
# 196807                      0.018124  0.021893  0.025563  0.009207  0.021511
# 196808                      0.036385  0.047524  0.052825  0.053510  0.038852
# 196809                      0.014603  0.017385  0.009723  0.010030  0.005645
# 196810                      0.068734  0.097077  0.068008  0.081080  0.083451
# 196811                     -0.008520 -0.027185 -0.017177 -0.016304 -0.042182
# 202205                     -0.009610           0.002784
# 202206                      0.033670           0.012416
#
# [648 rows x 92 columns]

# %%
date = '11_04_2023'

# %%
date = '11_04_2023'
file_name = 'results/grid_backtester_' + date +'.pkl'
with open(file_name, 'wb') as file:
    pickle.dump(backtester, file)
# config_returns.to_csv('results/config_returns_' + date +'.csv')
config_returns.reset_index().melt('Date').to_csv('results/melt_config_returns_' + date +'.csv')

# %%
melt_config_returns = pd.read_csv('results/melt_config_returns_' + date +'.csv')
melt_config_returns['Date'] = melt_config_returns['Date'].astype(str)
config_returns = melt_config_returns.pivot(index='Date', columns=['Strategy', 'TradingRule'], values='value')
config_returns
# Out:
# Strategy    NoPreprocessing Identity                                          \
# TradingRule                 decile-1  decile-2  decile-3  decile-4  decile-5
# Date
# 196807                      0.018124  0.021893  0.025563  0.009207  0.021511
# 196808                      0.036385  0.047524  0.052825  0.053510  0.038852
# 196809                      0.014603  0.017385  0.009723  0.010030  0.005645
# 196810                      0.068734  0.097077  0.068008  0.081080  0.083451
# 196811                     -0.008520 -0.027185 -0.017177 -0.016304 -0.042182
# ...                              ...       ...       ...       ...       ...
# 202202                      0.014220  0.002839  0.014794  0.006681  0.001937
# 202203                     -0.064034 -0.064539 -0.064967 -0.064214 -0.053519
# 202204                      0.027793  0.015695  0.007754  0.005933  0.010047
# 202205                     -0.083586 -0.079054 -0.090486 -0.054453 -0.059065
# 202206                      0.074709  0.085499  0.090896  0.080591  0.079553
#
# Strategy                                                       ...  \
# TradingRule  decile-6  decile-7  decile-8  decile-9 decile-10  ...
# Date                                                           ...
# 196807       0.024649  0.016379  0.029108 -0.013077  0.001829  ...
# 196808       0.031449  0.046399  0.051187  0.044796  0.051317  ...
# 196809       0.000765  0.022044  0.007207 -0.004294 -0.000073  ...
# 196810       0.074424  0.051507  0.050922  0.042783  0.040403  ...
# 196811      -0.032369 -0.031121 -0.061280 -0.031989 -0.049470  ...
# ...               ...       ...       ...       ...       ...  ...
# 202202       0.001321  0.009337  0.022543  0.031379  0.025038  ...
# 202203      -0.071386 -0.062270 -0.064759 -0.049963 -0.052309  ...
# 202204      -0.000624  0.019920  0.012548  0.012199  0.014075  ...
# 202205      -0.079629 -0.084662 -0.093210 -0.080502 -0.077361  ...
# 202206       0.089226  0.063585  0.079245  0.047803  0.024497  ...
#
# Strategy    Residuals LGMRF uniform-weighting                                \
# TradingRule                          decile-6  decile-7  decile-8  decile-9
# Date
# 196807                               0.011089  0.007662  0.005964  0.002626
# 196808                               0.030315  0.040275  0.053092  0.061456
# 196809                               0.023442 -0.000375 -0.016119 -0.008731
# 196810                               0.048667  0.068685  0.063648  0.065829
# 196811                              -0.036813 -0.027396 -0.025500 -0.017382
# ...                                       ...       ...       ...       ...
# 202202                               0.012985  0.007115  0.026854  0.006806
# 202203                              -0.062265 -0.059236 -0.059651 -0.062696
# 202204                               0.002553 -0.005316  0.011295 -0.000118
# 202205                              -0.064117 -0.078668 -0.069257 -0.082510
# 202206                               0.083855  0.072935  0.060980  0.052375
#
# Strategy                        NoPreprocessing Pairs-5 Residuals Pairs-5  \
# TradingRule decile-10     q=0.2                   std=2             std=2
# Date
# 196807      -0.039921  0.069238                0.052559          0.000000
# 196808       0.033051  0.016330                0.000000          0.043724
# 196809      -0.037247  0.073611               -0.040964         -0.101283
# 196810       0.072797 -0.043149               -0.011610          0.036990
# 196811      -0.015285 -0.046957               -0.065385          0.000000
# ...               ...       ...                     ...               ...
# 202202       0.024285 -0.010425               -0.005236          0.000000
# 202203      -0.073974  0.011569               -0.005858          0.000000
# 202204       0.000129  0.045050                0.000000          0.000608
# 202205      -0.052694 -0.070530               -0.025228          0.000000
# 202206       0.028414  0.057560                0.021607          0.000000
#
# Strategy    NoPreprocessing Pairs-20 Residuals Pairs-20
# TradingRule                    std=2              std=2
# Date
# 196807                      0.035396           0.000000
# 196808                      0.000000           0.031184
# 196809                     -0.063309          -0.019355
# 196810                      0.001736           0.023679
# 196811                     -0.003886           0.000000
# ...                              ...                ...
# 202202                      0.016645           0.012089
# 202203                      0.007094           0.000000
# 202204                     -0.007785           0.004928
# 202205                     -0.009610           0.002784
# 202206                      0.033670           0.012416
#
# [648 rows x 92 columns]

# %%
# config_returns += factors.loc[config_returns.index,['RF']].values / 100

# %%
melt_config_returns = config_returns.round(4).reset_index().melt('Date')
melt_config_returns
# Out:
#          Date                  Strategy TradingRule   value
# 0      196807  NoPreprocessing Identity    decile-1  0.0181
# 1      196808  NoPreprocessing Identity    decile-1  0.0364
# 2      196809  NoPreprocessing Identity    decile-1  0.0146
# 3      196810  NoPreprocessing Identity    decile-1  0.0687
# 4      196811  NoPreprocessing Identity    decile-1 -0.0085
# ...       ...                       ...         ...     ...
# 59611  202202        Residuals Pairs-20       std=2  0.0121
# 59612  202203        Residuals Pairs-20       std=2  0.0000
# 59613  202204        Residuals Pairs-20       std=2  0.0049
# 59614  202205        Residuals Pairs-20       std=2  0.0028
# 59615  202206        Residuals Pairs-20       std=2  0.0124
#
# [59616 rows x 4 columns]

# %%
filt_melt_config_returns = melt_config_returns[melt_config_returns['TradingRule'].str.startswith('decile')].copy()
filt_melt_config_returns['Decile'] = filt_melt_config_returns['TradingRule'].str.split('-', expand=True)[1].astype(np.int32)

# %%
window = 60
rolling_decile_returns = filt_melt_config_returns.pivot(index='Date', columns=['Decile', 'Strategy'], values='value').rolling(window).mean().dropna()

# %%
rolling_decile_returns.index = pd.to_datetime(rolling_decile_returns.index + '01')

# %%
rolling_decile_returns
# Out:
# Decile                           1                        2   \
# Strategy   NoPreprocessing Identity NoPreprocessing Identity
# Date
# 1973-06-01                 0.011565                 0.007332
# 1973-07-01                 0.010903                 0.006463
# 1973-08-01                 0.012162                 0.007487
# 1973-09-01                 0.012080                 0.007788
# 1973-10-01                 0.008625                 0.003440
# ...                             ...                      ...
# 2022-02-01                 0.013282                 0.011198
# 2022-03-01                 0.012228                 0.009955
# 2022-04-01                 0.013155                 0.010495
# 2022-05-01                 0.011205                 0.008672
# 2022-06-01                 0.012080                 0.009760
#
# Decile                           3                        4   \
# 4     1973-10-01      1           NoPreprocessing Identity  0.008625
# ...          ...    ...                                ...       ...
# 47115 2022-02-01     10  Residuals LGMRF uniform-weighting  0.002765
# 47116 2022-03-01     10  Residuals LGMRF uniform-weighting  0.001695
# 47117 2022-04-01     10  Residuals LGMRF uniform-weighting  0.001918
# 47118 2022-05-01     10  Residuals LGMRF uniform-weighting  0.000797
# 47119 2022-06-01     10  Residuals LGMRF uniform-weighting  0.001295
#
#          Preprocessing                  Trading
# 0      NoPreprocessing                 Identity
# 1      NoPreprocessing                 Identity
# 2      NoPreprocessing                 Identity
# 3      NoPreprocessing                 Identity
# 4      NoPreprocessing                 Identity
# ...                ...                      ...
# 47115        Residuals  LGMRF uniform-weighting
# 47116        Residuals  LGMRF uniform-weighting
# 47117        Residuals  LGMRF uniform-weighting
# 47118        Residuals  LGMRF uniform-weighting
# 47119        Residuals  LGMRF uniform-weighting
#
# [47120 rows x 6 columns]

# %%
rolling_mkt_rf = (factors['Mkt-RF'] / 100).rolling(window).mean().dropna()
rolling_mkt_rf.index = pd.to_datetime(rolling_mkt_rf.index + '01')
rolling_mkt_rf
# Out:
# 1968-06-01    0.006923
# 1968-07-01    0.006535
# 1968-08-01    0.005913
# 1968-09-01    0.006847
# 1968-10-01    0.006495
#                 ...
# 2022-05-01    0.010468
# 2022-06-01    0.008933
# 2022-07-01    0.010217
# 2022-08-01    0.009560
# 2022-09-01    0.007582
# Name: Mkt-RF, Length: 652, dtype: float64

# %%
g = sns.relplot(data=melt_rolling_decile_returns[melt_rolling_decile_returns['Decile'].isin([1, 5, 10])],
                x='Date', y='value', hue='Decile', row='Preprocessing', style='Trading',
                palette='tab10', aspect=5, kind='line')

for ax in g.axes[:, 0]:
    rolling_mkt_rf.loc[melt_rolling_decile_returns['Date']].plot(ax=ax, linewidth=2, color='grey')
    # ax.axhline(0, ls='--', linewidth=3, color='grey')
plt.show()

# %%
rolling_decile_diff_returns = rolling_decile_returns - rolling_decile_returns[10]  # [[(10, 'NoPreprocessing Identity')]].values
melt_rolling_decile_diff_returns = rolling_decile_diff_returns.reset_index().melt('Date')
melt_rolling_decile_diff_returns['Preprocessing']= melt_rolling_decile_diff_returns['Strategy'].apply(lambda x: x.split(' ')[0])
melt_rolling_decile_diff_returns['Trading']= melt_rolling_decile_diff_returns['Strategy'].apply(lambda x: ' '.join(x.split(' ')[1:]))
melt_rolling_decile_diff_returns
# Out:
#             Date Decile                           Strategy     value  \
# 0     1973-06-01      1           NoPreprocessing Identity  0.022365
# 1     1973-07-01      1           NoPreprocessing Identity  0.022218
# 2     1973-08-01      1           NoPreprocessing Identity  0.023178
# 3     1973-09-01      1           NoPreprocessing Identity  0.022777
# 4     1973-10-01      1           NoPreprocessing Identity  0.021953
# ...          ...    ...                                ...       ...
# 47115 2022-02-01     10  Residuals LGMRF uniform-weighting  0.000000
# 47116 2022-03-01     10  Residuals LGMRF uniform-weighting  0.000000
# 47117 2022-04-01     10  Residuals LGMRF uniform-weighting  0.000000
# 47118 2022-05-01     10  Residuals LGMRF uniform-weighting  0.000000
# 47119 2022-06-01     10  Residuals LGMRF uniform-weighting  0.000000
#
#          Preprocessing                  Trading
# 0      NoPreprocessing                 Identity
# 1      NoPreprocessing                 Identity
# 2      NoPreprocessing                 Identity
# 3      NoPreprocessing                 Identity
# 4      NoPreprocessing                 Identity
# ...                ...                      ...
# 47115        Residuals  LGMRF uniform-weighting
# 47116        Residuals  LGMRF uniform-weighting
# 47117        Residuals  LGMRF uniform-weighting
# 47118        Residuals  LGMRF uniform-weighting
# 47119        Residuals  LGMRF uniform-weighting
#
# [47120 rows x 6 columns]

# %%
g = sns.relplot(data=melt_rolling_decile_diff_returns[melt_rolling_decile_returns['Decile'].isin([1, 5, 10])],
                x='Date', y='value', hue='Decile', row='Preprocessing', style='Trading',
                palette='tab10', aspect=5, kind='line')

for ax in g.axes[:, 0]:
    ax.axhline(0, ls='--', linewidth=2, color='grey')
plt.show()

# %%
melt_config_cum_returns = (1 + config_returns).cumprod().reset_index().melt('Date')
melt_config_cum_returns['Date'] = pd.to_datetime(melt_config_cum_returns['Date']+'01')
melt_config_cum_returns['Preprocessing'] = melt_config_cum_returns['Strategy'].str.split(expand=True)[0]
melt_config_cum_returns['Trader'] = melt_config_cum_returns['Strategy'].str.split(expand=True)[1] # + ' ' + melt_config_cum_returns['Strategy'].str.split(expand=True)[2].fillna('')
melt_config_cum_returns
# Out:
#             Date                  Strategy TradingRule        value  \
# 0     1968-07-01  NoPreprocessing Identity    decile-1     1.018124
# 1     1968-08-01  NoPreprocessing Identity    decile-1     1.055168
# 2     1968-09-01  NoPreprocessing Identity    decile-1     1.070577
# 3     1968-10-01  NoPreprocessing Identity    decile-1     1.144163
# 4     1968-11-01  NoPreprocessing Identity    decile-1     1.134414
# ...          ...                       ...         ...          ...
# 59611 2022-02-01        Residuals Pairs-20       std=2  1792.685770
# 59612 2022-03-01        Residuals Pairs-20       std=2  1792.685770
# 59613 2022-04-01        Residuals Pairs-20       std=2  1801.519685
# 59614 2022-05-01        Residuals Pairs-20       std=2  1806.534386
# 59615 2022-06-01        Residuals Pairs-20       std=2  1828.964390
#
#          Preprocessing    Trader
# 0      NoPreprocessing  Identity
# 1      NoPreprocessing  Identity
# 2      NoPreprocessing  Identity
# 3      NoPreprocessing  Identity
# 4      NoPreprocessing  Identity
# ...                ...       ...
# 59611        Residuals  Pairs-20
# 59612        Residuals  Pairs-20
# 59613        Residuals  Pairs-20
# 59614        Residuals  Pairs-20
# 59615        Residuals  Pairs-20
#
# [59616 rows x 6 columns]

# %%
def one_factor_alpha(x):
    monthly_alpha = LinearRegression().fit(factors_rf[['Mkt-RF']].loc[x.index], x).intercept_
    return ((1 + monthly_alpha) ** 12 - 1) * 100

def five_factors_alpha(x):
    monthly_alpha = LinearRegression().fit(factors_rf.loc[x.index], x).intercept_
    return ((1 + monthly_alpha) ** 12 - 1) * 100

def stat_arb_bench_alpha(x):
    monthly_alpha = LinearRegression().fit(factors_rf_bench[['benchmark']], x).intercept_
    return ((1 + monthly_alpha) ** 12 - 1) * 100

def stat_arb_bench_beta(x):
    beta = LinearRegression().fit(factors_rf_bench[['benchmark']], x).coef_[0]
    return beta

factors_rf_bench = factors_rf.loc[config_returns.index].copy()
factors_rf_bench['benchmark'] = config_returns['NoPreprocessing Identity']['q=0.2']
# factors_rf_bench['benchmark'] = factors_rf.loc[config_returns.index]['Mkt-RF']

def five_plus_bench_factors_beta(x):
    beta = LinearRegression().fit(factors_rf_bench, x).coef_[-1]
    return beta

def five_plus_bench_factors_alpha(x):
    monthly_alpha = LinearRegression().fit(factors_rf_bench, x).intercept_
    return ((1 + monthly_alpha) ** 12 - 1) * 100

# %%
config_returns
# Out:
# Strategy    NoPreprocessing Identity                                          \
# TradingRule                 decile-1  decile-2  decile-3  decile-4  decile-5
# Date
# 196807                      0.018124  0.021893  0.025563  0.009207  0.021511
# 196808                      0.036385  0.047524  0.052825  0.053510  0.038852
# 196809                      0.014603  0.017385  0.009723  0.010030  0.005645
# 196810                      0.068734  0.097077  0.068008  0.081080  0.083451
# 196811                     -0.008520 -0.027185 -0.017177 -0.016304 -0.042182
# ...                              ...       ...       ...       ...       ...
# 202202                      0.014220  0.002839  0.014794  0.006681  0.001937
# 202203                     -0.064034 -0.064539 -0.064967 -0.064214 -0.053519
# 202204                      0.027793  0.015695  0.007754  0.005933  0.010047
# 202205                     -0.083586 -0.079054 -0.090486 -0.054453 -0.059065
# 202206                      0.074709  0.085499  0.090896  0.080591  0.079553
#
# Strategy                                                       ...  \
# TradingRule  decile-6  decile-7  decile-8  decile-9 decile-10  ...
# Date                                                           ...
# 196807       0.024649  0.016379  0.029108 -0.013077  0.001829  ...
# 196808       0.031449  0.046399  0.051187  0.044796  0.051317  ...
# 196809       0.000765  0.022044  0.007207 -0.004294 -0.000073  ...
# 196810       0.074424  0.051507  0.050922  0.042783  0.040403  ...
# 196811      -0.032369 -0.031121 -0.061280 -0.031989 -0.049470  ...
# ...               ...       ...       ...       ...       ...  ...
# 202202       0.001321  0.009337  0.022543  0.031379  0.025038  ...
# 202203      -0.071386 -0.062270 -0.064759 -0.049963 -0.052309  ...
# 202204      -0.000624  0.019920  0.012548  0.012199  0.014075  ...
# 202205      -0.079629 -0.084662 -0.093210 -0.080502 -0.077361  ...
# 202206       0.089226  0.063585  0.079245  0.047803  0.024497  ...
#
# Strategy    Residuals LGMRF uniform-weighting                                \
# TradingRule                          decile-6  decile-7  decile-8  decile-9
# Date
# 196807                               0.011089  0.007662  0.005964  0.002626
# 196808                               0.030315  0.040275  0.053092  0.061456
# 196809                               0.023442 -0.000375 -0.016119 -0.008731
# 196810                               0.048667  0.068685  0.063648  0.065829
# 196811                              -0.036813 -0.027396 -0.025500 -0.017382
# ...                                       ...       ...       ...       ...
# 202202                               0.012985  0.007115  0.026854  0.006806
# 202203                              -0.062265 -0.059236 -0.059651 -0.062696
# 202204                               0.002553 -0.005316  0.011295 -0.000118
# 202205                              -0.064117 -0.078668 -0.069257 -0.082510
# 202206                               0.083855  0.072935  0.060980  0.052375
#
# Strategy                        NoPreprocessing Pairs-5 Residuals Pairs-5  \
# TradingRule decile-10     q=0.2                   std=2             std=2
# Date
# 196807      -0.039921  0.069238                0.052559          0.000000
# 196808       0.033051  0.016330                0.000000          0.043724
# 196809      -0.037247  0.073611               -0.040964         -0.101283
# 196810       0.072797 -0.043149               -0.011610          0.036990
# 196811      -0.015285 -0.046957               -0.065385          0.000000
# ...               ...       ...                     ...               ...
# 202202       0.024285 -0.010425               -0.005236          0.000000
# 202203      -0.073974  0.011569               -0.005858          0.000000
# 202204       0.000129  0.045050                0.000000          0.000608
# 202205      -0.052694 -0.070530               -0.025228          0.000000
# 202206       0.028414  0.057560                0.021607          0.000000
#
# Strategy    NoPreprocessing Pairs-20 Residuals Pairs-20
# TradingRule                    std=2              std=2
# Date
# 196807                      0.035396           0.000000
# 196808                      0.000000           0.031184
# 196809                     -0.063309          -0.019355
# 196810                      0.001736           0.023679
# 196811                     -0.003886           0.000000
# ...                              ...                ...
# 202202                      0.016645           0.012089
# 202203                      0.007094           0.000000
# 202204                     -0.007785           0.004928
# 202205                     -0.009610           0.002784
# 202206                      0.033670           0.012416
#
# [648 rows x 92 columns]

# %%
config_decile_returns = filt_melt_config_returns.pivot(index='Date', columns=['Strategy', 'Decile'], values='value')
results_df_decile = config_decile_returns.apply(lambda x: pd.Series(
    {'expected return': round(((1 + np.mean(x)) ** 12 - 1)*100, 2), 'return std': round(np.std(x * 100), 2),
     # 'sharpe': sharpe_ratio(x), 'sortino': sortino_ratio(x),
     # '1-factor alpha': one_factor_alpha(x), '5-factors alpha': five_factors_alpha(x),
     # 'benchmark beta': stat_arb_bench_beta(x), 'benchmark alpha': stat_arb_bench_alpha(x),
     # '5-factors - benchmark beta': five_plus_bench_factors_beta(x), 
     # '5-factors - benchmark alpha': five_plus_bench_factors_alpha(x)
    })).T.sort_index()
results_df_decile
# Out:
#                                           expected return  return std
# Strategy                          Decile
# NoPreprocessing Corr-50           1                 22.23        5.11
#                                   2                 16.40        4.79
#                                   3                 13.72        4.69
#                                   4                 10.32        4.48
#                                   5                  8.45        4.36
# ...                                                   ...         ...
# Residuals LGMRF uniform-weighting 6                  6.91        4.17
#                                   7                  5.05        4.31
#                                   8                  3.25        4.56
#                                   9                 -0.17        4.78
#                                   10                -6.71        5.65
#
# [80 rows x 2 columns]

# %%
k = 2
q_left = 1 - k / results_df_decile.reset_index()['Strategy'].nunique()
results_df_decile.reset_index().melt(['Strategy', 'Decile']).pivot(index=['Decile', 'variable'], columns='Strategy', values='value').round(2).\
    style.\
    highlight_quantile(q_left=q_left, axis=1).\
    highlight_max(color='lightgreen', axis=1).\
    highlight_quantile(q_right=1-q_left, color='pink', axis=1).\
    highlight_min(color='red', axis=1).\
    format('{:.2f}')
# Out:
# <style type="text/css">
# #T_d95ad_row0_col1, #T_d95ad_row1_col0, #T_d95ad_row2_col1, #T_d95ad_row3_col6, #T_d95ad_row4_col1, #T_d95ad_row5_col6, #T_d95ad_row5_col7, #T_d95ad_row6_col0, #T_d95ad_row7_col4, #T_d95ad_row8_col5, #T_d95ad_row9_col4, #T_d95ad_row9_col6, #T_d95ad_row10_col0, #T_d95ad_row11_col6, #T_d95ad_row12_col6, #T_d95ad_row13_col2, #T_d95ad_row13_col3, #T_d95ad_row14_col0, #T_d95ad_row15_col0, #T_d95ad_row15_col1, #T_d95ad_row15_col3, #T_d95ad_row16_col7, #T_d95ad_row17_col2, #T_d95ad_row18_col7, #T_d95ad_row19_col1 {
#   background-color: pink;
#   background-color: red;
# }
# #T_d95ad_row0_col3, #T_d95ad_row1_col3, #T_d95ad_row2_col0, #T_d95ad_row3_col4, #T_d95ad_row4_col2, #T_d95ad_row6_col2, #T_d95ad_row7_col7, #T_d95ad_row8_col0, #T_d95ad_row10_col2, #T_d95ad_row11_col7, #T_d95ad_row12_col3, #T_d95ad_row14_col3, #T_d95ad_row16_col5, #T_d95ad_row17_col3, #T_d95ad_row18_col4, #T_d95ad_row19_col0 {
#   background-color: pink;
# }
# #T_d95ad_row0_col6, #T_d95ad_row1_col6, #T_d95ad_row1_col7, #T_d95ad_row2_col6, #T_d95ad_row3_col3, #T_d95ad_row4_col4, #T_d95ad_row5_col1, #T_d95ad_row6_col6, #T_d95ad_row7_col1, #T_d95ad_row8_col4, #T_d95ad_row9_col1, #T_d95ad_row10_col5, #T_d95ad_row11_col2, #T_d95ad_row12_col1, #T_d95ad_row13_col5, #T_d95ad_row14_col1, #T_d95ad_row15_col5, #T_d95ad_row16_col1, #T_d95ad_row17_col5, #T_d95ad_row18_col1, #T_d95ad_row19_col7 {
#   background-color: yellow;
#   background-color: lightgreen;
# }
# #T_d95ad_row0_col7, #T_d95ad_row2_col7, #T_d95ad_row3_col1, #T_d95ad_row3_col2, #T_d95ad_row4_col7, #T_d95ad_row5_col0, #T_d95ad_row6_col4, #T_d95ad_row7_col2, #T_d95ad_row7_col3, #T_d95ad_row8_col6, #T_d95ad_row9_col3, #T_d95ad_row10_col1, #T_d95ad_row11_col0, #T_d95ad_row11_col1, #T_d95ad_row12_col5, #T_d95ad_row13_col6, #T_d95ad_row14_col7, #T_d95ad_row15_col7, #T_d95ad_row16_col3, #T_d95ad_row17_col6, #T_d95ad_row18_col3, #T_d95ad_row19_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d95ad">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Strategy</th>
#       <th id="T_d95ad_level0_col0" class="col_heading level0 col0" >NoPreprocessing Corr-50</th>
#       <th id="T_d95ad_level0_col1" class="col_heading level0 col1" >NoPreprocessing Identity</th>
#       <th id="T_d95ad_level0_col2" class="col_heading level0 col2" >NoPreprocessing LGMRF</th>
#       <th id="T_d95ad_level0_col3" class="col_heading level0 col3" >NoPreprocessing LGMRF uniform-weighting</th>
#       <th id="T_d95ad_level0_col4" class="col_heading level0 col4" >Residuals Corr-50</th>
#       <th id="T_d95ad_level0_col5" class="col_heading level0 col5" >Residuals Identity</th>
#       <th id="T_d95ad_level0_col6" class="col_heading level0 col6" >Residuals LGMRF</th>
#       <th id="T_d95ad_level0_col7" class="col_heading level0 col7" >Residuals LGMRF uniform-weighting</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Decile</th>
#       <th class="index_name level1" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_d95ad_level1_row5" class="row_heading level1 row5" >return std</th>
#       <td id="T_d95ad_row5_col0" class="data row5 col0" >4.69</td>
#       <td id="T_d95ad_row5_col1" class="data row5 col1" >4.82</td>
#       <td id="T_d95ad_row5_col2" class="data row5 col2" >4.64</td>
#       <td id="T_d95ad_row5_col3" class="data row5 col3" >4.67</td>
#       <td id="T_d95ad_row5_col4" class="data row5 col4" >4.41</td>
#       <td id="T_d95ad_row5_col5" class="data row5 col5" >4.40</td>
#       <td id="T_d95ad_row5_col6" class="data row5 col6" >4.35</td>
#       <td id="T_d95ad_row5_col7" class="data row5 col7" >4.35</td>
#     </tr>
#     <tr>
#       <th id="T_d95ad_level0_row6" class="row_heading level0 row6" rowspan="2">4</th>
#       <th id="T_d95ad_level1_row6" class="row_heading level1 row6" >expected return</th>
#       <td id="T_d95ad_row6_col0" class="data row6 col0" >10.32</td>
#       <td id="T_d95ad_row6_col1" class="data row6 col1" >10.56</td>
#       <td id="T_d95ad_row6_col2" class="data row6 col2" >10.33</td>
#       <td id="T_d95ad_row6_col3" class="data row6 col3" >10.37</td>
#       <td id="T_d95ad_row6_col4" class="data row6 col4" >11.16</td>
#       <td id="T_d

# %%
config_returns
# Out:
# Strategy    NoPreprocessing Identity                                          \
# TradingRule                 decile-1  decile-2  decile-3  decile-4  decile-5
# Date
# 196807                      0.018124  0.021893  0.025563  0.009207  0.021511
# 196808                      0.036385  0.047524  0.052825  0.053510  0.038852
# 196809                      0.014603  0.017385  0.009723  0.010030  0.005645
# 196810                      0.068734  0.097077  0.068008  0.081080  0.083451
# 196811                     -0.008520 -0.027185 -0.017177 -0.016304 -0.042182
# ...                              ...       ...       ...       ...       ...
# 202202                      0.014220  0.002839  0.014794  0.006681  0.001937
# 202203                     -0.064034 -0.064539 -0.064967 -0.064214 -0.053519
# 202204                      0.027793  0.015695  0.007754  0.005933  0.010047
# 202205                     -0.083586 -0.079054 -0.090486 -0.054453 -0.059065
# 202206                      0.074709  0.085499  0.090896  0.080591  0.079553
#
# Strategy                                                       ...  \
# TradingRule  decile-6  decile-7  decile-8  decile-9 decile-10  ...
# Date                                                           ...
# 196807       0.024649  0.016379  0.029108 -0.013077  0.001829  ...
# 196808       0.031449  0.046399  0.051187  0.044796  0.051317  ...
# 196809       0.000765  0.022044  0.007207 -0.004294 -0.000073  ...
# 196810       0.074424  0.051507  0.050922  0.042783  0.040403  ...
# 196811      -0.032369 -0.031121 -0.061280 -0.031989 -0.049470  ...
# ...               ...       ...       ...       ...       ...  ...
# 202202       0.001321  0.009337  0.022543  0.031379  0.025038  ...
# 202203      -0.071386 -0.062270 -0.064759 -0.049963 -0.052309  ...
# 202204      -0.000624  0.019920  0.012548  0.012199  0.014075  ...
# 202205      -0.079629 -0.084662 -0.093210 -0.080502 -0.077361  ...
# 202206       0.089226  0.063585  0.079245  0.047803  0.024497  ...
#
# Strategy    Residuals Corr-50                                          \
# TradingRule          decile-6  decile-7  decile-8  decile-9 decile-10
# Date
# 196807               0.008569  0.016926 -0.005706  0.002956 -0.037379
# 196808               0.052154  0.033127  0.064404  0.047210  0.037511
# 196809               0.007723  0.013341 -0.013041 -0.023109 -0.034130
# 196810               0.061925  0.068640  0.057409  0.059132  0.073991
# 196811              -0.022142 -0.033180 -0.032644 -0.016353 -0.015709
# ...                       ...       ...       ...       ...       ...
# 202202               0.005163  0.011775  0.027004  0.002774  0.024250
# 202203              -0.059866 -0.065972 -0.058636 -0.061657 -0.073642
# 202204               0.005055  0.003153 -0.003201  0.001678  0.002714
# 202205              -0.071740 -0.076864 -0.078341 -0.080895 -0.050206
# 202206               0.086342  0.063941  0.066840  0.053078  0.025008
#
# Strategy              NoPreprocessing Pairs-5 Residuals Pairs-5  \
# TradingRule     q=0.2                   std=2             std=2
# Date
# 196807       0.076648                0.052559          0.000000
# 196808       0.015044                0.000000          0.043724
# 196809       0.066680               -0.040964         -0.101283
# 196810      -0.046901               -0.011610          0.036990
# 196811      -0.041309               -0.065385          0.000000
# ...               ...                     ...               ...
# 202202      -0.004209               -0.005236          0.000000
# 202203       0.014623               -0.005858          0.000000
# 202204       0.037207                0.000000          0.000608
# 202205      -0.067301               -0.025228          0.000000
# 202206       0.060411                0.021607          0.000000
#
# Strategy    NoPreprocessing Pairs-20 Residuals Pairs-20
# TradingRule                    std=2              std=2
# Date
# 196807                      0.035396           0.000000
# 196808                      0.000000           0.031184
# 196809                     -0.063309          -0.019355
# 196810                      0.001736           0.023679
# 196811                     -0.003886           0.000000
# ...                              ...                ...
# 202202                      0.016645           0.012089
# 202203                      0.007094           0.000000
# 202204                     -0.007785           0.004928
# 202205                     -0.009610           0.002784
# 202206                      0.033670           0.012416
#
# [648 rows x 48 columns]

# %%
stat_arb_returns = config_returns.loc[:, config_returns.columns.map(lambda x: not x[1].startswith('decile'))].droplevel('TradingRule', axis=1)

# %%
results_df = stat_arb_returns.apply(lambda x: pd.Series(
    {'expected return': ((1 + np.mean(x)) ** 12 - 1)*100, 'std': np.std(x),
     'sharpe': sharpe_ratio(x), 'sortino': sortino_ratio(x),
     '1-factor alpha': one_factor_alpha(x), '5-factors alpha': five_factors_alpha(x),
     'benchmark beta': stat_arb_bench_beta(x), 'benchmark alpha': stat_arb_bench_alpha(x),
     # '5-factors - benchmark beta': five_plus_bench_factors_beta(x), 
     '5-factors - benchmark alpha': five_plus_bench_factors_alpha(x)})).T.sort_index()

# %%
k = 3
q_left = 1 - k / len(results_df)
results_df.round(2).drop(columns='std')\
    .style.\
    highlight_quantile(q_left=q_left).\
    highlight_max(color='lightgreen').\
    highlight_quantile(q_right=1-q_left, color='pink').\
    highlight_min(color='red').\
    format('{:.2f}')
# Out:
# <style type="text/css">
td>
#     </tr>
#     <tr>
#       <th id="T_45e0d_level0_row6" class="row_heading level0 row6" >Residuals Corr-50</th>
#       <td id="T_45e0d_row6_col0" class="data row6 col0" >33.33</td>
#       <td id="T_45e0d_row6_col1" class="data row6 col1" >1.56</td>
#       <td id="T_45e0d_row6_col2" class="data row6 col2" >2.56</td>
#       <td id="T_45e0d_row6_col3" class="data row6 col3" >32.99</td>
#       <td id="T_45e0d_row6_col4" class="data row6 col4" >30.36</td>
#       <td id="T_45e0d_row6_col5" class="data row6 col5" >-0.16</td>
#       <td id="T_45e0d_row6_col6" class="data row6 col6" >37.75</td>
#       <td id="T_45e0d_row6_col7" class="data row6 col7" >34.56</td>
#     </tr>
#     <tr>
#       <th id="T_45e0d_level0_row7" class="row_heading level0 row7" >Residuals Identity</th>
#       <td id="T_45e0d_row7_col0" class="data row7 col0" >32.00</td>
#       <td id="T_45e0d_row7_col1" class="data row7 col1" >1.43</td>
#       <td id="T_45e0d_row7_col2" class="data row7 col2" >2.26</td>
#       <td id="T_45e0d_row7_col3" class="data row7 col3" >31.59</td>
#       <td id="T_45e0d_row7_col4" class="data row7 col4" >29.23</td>
#       <td id="T_45e0d_row7_col5" class="data row7 col5" >-0.08</td>
#       <td id="T_45e0d_row7_col6" class="data row7 col6" >34.08</td>
#       <td id="T_45e0d_row7_col7" class="data row7 col7" >31.04</td>
#     </tr>
#     <tr>
#       <th id="T_45e0d_level0_row8" class="row_heading level0 row8" >Residuals LGMRF</th>
#       <td id="T_45e0d_row8_col0" class="data row8 col0" >33.33</td>
#       <td id="T_45e0d_row8_col1" class="data row8 col1" >1.57</td>
#       <td id="T_45e0d_row8_col2" class="data row8 col2" >2.51</td>
#       <td id="T_45e0d_row8_col3" class="data row

# %%
factors_rf_alpha = factors_rf.copy()
factors_rf_alpha['alpha'] = 1.
window = 60
rolling_alpha_df = pd.DataFrame({col: RollingOLS(stat_arb_returns[col], factors_rf_alpha.loc[stat_arb_returns.index], window=window).fit().params['alpha'] for col in stat_arb_returns.columns},
                                index=stat_arb_returns.index).dropna()
rolling_alpha_df = ((1 + rolling_alpha_df) ** 12 - 1) * 100

rolling_alpha_pval_df = pd.DataFrame({col: RollingOLS(stat_arb_returns[col], factors_rf_alpha.loc[stat_arb_returns.index], window=window).fit().pvalues[:, -1] for col in stat_arb_returns.columns},
             index=stat_arb_returns.index).dropna()

# %%
sp500_index_returns = pd.read_csv('data/sp500_returns.csv', parse_dates=['Date'])
returns = sp500_index_returns.set_index('Date').loc[pd.to_datetime(stat_arb_returns.index + '01')]
am = arch.arch_model(returns * 100, vol="Garch", p=1, o=0, q=1, dist="Normal")
forecasts = {}
for i in range(len(returns)- window):
    res = am.fit(first_obs=i, last_obs=i + window, disp="off")
    temp = np.sqrt(res.forecast(horizon=1, reindex=False).variance)
    # temp = res.forecast(horizon=1, reindex=False).variance
    fcast = temp.iloc[0]
    forecasts[fcast.name] = fcast
    
garch_vol = pd.DataFrame(forecasts).T.reset_index().rename(columns={'h.1': 'Garch Vol.', 
                                                                    'index': 'Date'})
garch_vol
# Out:
#           Date  Garch Vol.
# 0   1973-06-01    3.233294
# 1   1973-07-01    3.289245
# 2   1973-08-01    3.372603
# 3   1973-09-01    2.940990
# 4   1973-10-01    4.650379
# ..         ...         ...
# 583 2022-01-01    4.613939
# 584 2022-02-01    3.876305
# 585 2022-03-01    6.880189
# 586 2022-04-01    4.135906
# 587 2022-05-01    6.515388
#
# [588 rows x 2 columns]

# %%
rolling_expected_returns_df_melt
# Out:
#         Date                  Strategy      value            Metric
# 0     197306  NoPreprocessing Identity  30.389154  expected returns
# 1     197307  NoPreprocessing Identity  30.166100  expected returns
# 2     197308  NoPreprocessing Identity  31.642609  expected returns
# 3     197309  NoPreprocessing Identity  31.024884  expected returns
# 4     197310  NoPreprocessing Identity  29.764038  expected returns
# ...      ...                       ...        ...               ...
# 7063  202202        Residuals Pairs-20   9.323624  expected returns
# 7064  202203        Residuals Pairs-20   9.107952  expected returns
# 7065  202204        Residuals Pairs-20   9.214753  expected returns
# 7066  202205        Residuals Pairs-20   8.908351  expected returns
# 7067  202206        Residuals Pairs-20   9.177181  expected returns
#
# [7068 rows x 4 columns]

# %%
# selected_cols = ['NoPreprocessing Identity', 'NoPreprocessing Corr-50', 'NoPreprocessing LGMRF uniform-weighting',
#         'Residuals Corr-50', 'Residuals Identity', 'Residuals LGMRF uniform-weighting', 'Residuals Pairs-20']
selected_cols = ['NoPreprocessing Identity', 'NoPreprocessing Corr-50',
                 'Residuals Identity', 'Residuals Corr-50']
selected_cols = rolling_alpha_df.columns

rolling_alpha_df_melt = rolling_alpha_df[selected_cols].reset_index().melt('Date')
rolling_alpha_df_melt['Metric'] = 'alpha'
rolling_alpha_pval_df_melt = rolling_alpha_pval_df[selected_cols].reset_index().melt('Date')
rolling_alpha_pval_df_melt['Metric'] = 'p-value'
rolling_expected_returns_df = stat_arb_returns.rolling(window).mean().dropna()
rolling_expected_returns_df = ((1 + rolling_expected_returns_df) ** 12 - 1) * 100
rolling_expected_returns_df_melt = rolling_expected_returns_df[selected_cols].reset_index().melt('Date').rename(columns={'Strategy': 'variable'})
rolling_expected_returns_df_melt['Metric'] = 'expected returns'

rolling_alpha_plots_df_melt = pd.concat([
    rolling_expected_returns_df_melt,
    rolling_alpha_df_melt,
    rolling_alpha_pval_df_melt,
])
rolling_alpha_plots_df_melt['Date'] = pd.to_datetime(rolling_alpha_plots_df_melt['Date'] + '01')
rolling_alpha_plots_df_melt['Preprocessing'] = rolling_alpha_plots_df_melt['variable'].str.split(expand=True)[0]
rolling_alpha_plots_df_melt['Strategy'] = rolling_alpha_plots_df_melt['variable'].str.split(expand=True)[1] + ' ' + rolling_alpha_plots_df_melt['variable'].str.split(expand=True)[2].fillna('')

rolling_alpha_plots_df_melt
# Out:
#            Date                  variable      value            Metric  \
# 0    1973-06-01  NoPreprocessing Identity  30.389154  expected returns
# 1    1973-07-01  NoPreprocessing Identity  30.166100  expected returns
# 2    1973-08-01  NoPreprocessing Identity  31.642609  expected returns
# 3    1973-09-01  NoPreprocessing Identity  31.024884  expected returns
# 4    1973-10-01  NoPreprocessing Identity  29.764038  expected returns
# ...         ...                       ...        ...               ...
# 7063 2022-02-01        Residuals Pairs-20   0.124762           p-value
# 7064 2022-03-01        Residuals Pairs-20   0.128192           p-value
# 7065 2022-04-01        Residuals Pairs-20   0.117438           p-value
# 7066 2022-05-01        Residuals Pairs-20   0.121448           p-value
# 7067 2022-06-01        Residuals Pairs-20   0.126014           p-value
#
#         Preprocessing   Strategy
# 0     NoPreprocessing  Identity
# 1     NoPreprocessing  Identity
# 2     NoPreprocessing  Identity
# 3     NoPreprocessing  Identity
# 4     NoPreprocessing  Identity
# ...               ...        ...
# 7063        Residuals  Pairs-20
# 7064        Residuals  Pairs-20
# 7065        Residuals  Pairs-20
# 7066        Residuals  Pairs-20
# 7067        Residuals  Pairs-20
#
# [21204 rows x 6 columns]

# %%
# fig, ax = plt.subplots(figsize=(16, 10))
sns.relplot(data=rolling_alpha_plots_df_melt, x='Date', y='value', 
            hue='Strategy', style='Preprocessing', 
            row='Metric', kind='line', aspect=3, facet_kws=dict(sharey=False))
plt.show()
# sns.lineplot(data=garch_vol, x='Date', y='Garch Vol.')

# %%
rolling_alpha_plots_df_melt['Category'] = rolling_alpha_plots_df_melt['Strategy'].apply(lambda x: 'Pairs' if x.startswith('Pairs') else "Spreads")

# %%
col = 'Preprocessing'
row = 'Metric'
x = 'Date'
y = 'value'
hue = 'Category'
row_vals = rolling_alpha_plots_df_melt[row].unique()
col_vals = rolling_alpha_plots_df_melt[col].unique()

fig, axs = plt.subplots(row_vals.size, col_vals.size, figsize=(20, 15))

for i, row_val in enumerate(row_vals):
    for j, col_val in enumerate(col_vals):
        sns.lineplot(data=rolling_alpha_plots_df_melt[((rolling_alpha_plots_df_melt[col] == col_val) & 
                                                       (rolling_alpha_plots_df_melt[row] == row_val))], 
                     x = x, y=y, hue=hue,
                     ax=axs[i, j])
        ax2 = axs[i, j].twinx()
        ax2.plot(garch_vol['Date'], garch_vol['Garch Vol.'], color='tab:green')
        if row_val != 'p-value':
            axs[i, j].axhline(0, color='black', ls='--')
        else:
            axs[i, j].set_ylim(-.1, 1.1)
            axs[i, j].axhline(0.05, color='black', ls='--')
        axs[i, j].set_title(f'{row} = {row_val} | {col} = {col_val}')

# %%
# window = 12
aux_df = rolling_alpha_plots_df_melt.groupby(['Date', 'Metric', 'Preprocessing'])['value'].mean().reset_index()
aux_df['Configuration'] = aux_df['Preprocessing'] + ' ' + aux_df['Metric']
aux_df = aux_df.pivot(index='Date', columns='Configuration', values='value').reset_index().merge(garch_vol).drop(columns='Date')
aux_df.corr()[['Garch Vol.']].drop('Garch Vol.').round(4).sort_index() #.sort_values('Garch Vol.')
# Out:
#                                   Garch Vol.
# NoPreprocessing alpha                 0.2526
# NoPreprocessing expected returns      0.2577
# NoPreprocessing p-value              -0.1310
# Residuals alpha                       0.3662
# Residuals expected returns            0.2682
# Residuals p-value                    -0.3049

# %%
# window = 60
aux_df = rolling_alpha_plots_df_melt.groupby(['Date', 'Metric', 'Preprocessing'])['value'].mean().reset_index()
aux_df['Configuration'] = aux_df['Preprocessing'] + ' ' + aux_df['Metric']
aux_df = aux_df.pivot(index='Date', columns='Configuration', values='value').reset_index().merge(garch_vol).drop(columns='Date')
aux_df.corr()[['Garch Vol.']].drop('Garch Vol.').round(4).sort_index() #.sort_values('Garch Vol.')
# Out:
#                                   Garch Vol.
# NoPreprocessing alpha                 0.2526
# NoPreprocessing expected returns      0.2577
# NoPreprocessing p-value              -0.1310
# Residuals alpha                       0.3662
# Residuals expected returns            0.2682
# Residuals p-value                    -0.3049

# %%
# window = 120
aux_df = rolling_alpha_plots_df_melt.groupby(['Date', 'Metric', 'Preprocessing'])['value'].mean().reset_index()
aux_df['Configuration'] = aux_df['Preprocessing'] + ' ' + aux_df['Metric']
aux_df = aux_df.pivot(index='Date', columns='Configuration', values='value').reset_index().merge(garch_vol).drop(columns='Date')
aux_df.corr()[['Garch Vol.']].drop('Garch Vol.').round(4).sort_index() #.sort_values('Garch Vol.')
# Out:
#                                   Garch Vol.
# NoPreprocessing alpha                 0.2526
# NoPreprocessing expected returns      0.2577
# NoPreprocessing p-value              -0.1310
# Residuals alpha                       0.3662
# Residuals expected returns            0.2682
# Residuals p-value                    -0.3049

# %%
# window = 240
aux_df = rolling_alpha_plots_df_melt.groupby(['Date', 'Metric', 'Preprocessing'])['value'].mean().reset_index()
aux_df['Configuration'] = aux_df['Preprocessing'] + ' ' + aux_df['Metric']
aux_df = aux_df.pivot(index='Date', columns='Configuration', values='value').reset_index().merge(garch_vol).drop(columns='Date')
aux_df.corr()[['Garch Vol.']].drop('Garch Vol.').round(4).sort_index() #.sort_values('Garch Vol.')
# Out:
#                                   Garch Vol.
# NoPreprocessing alpha                 0.2526
# NoPreprocessing expected returns      0.2577
# NoPreprocessing p-value              -0.1310
# Residuals alpha                       0.3662
# Residuals expected returns            0.2682
# Residuals p-value                    -0.3049

# %%
rolling_alpha_plots_df_melt[((rolling_alpha_plots_df_melt['Metric'] == 'p-value') &
                             (rolling_alpha_plots_df_melt['Preprocessing'] == 'NoPreprocessing'))].groupby(['Preprocessing', 'Strategy'])[['value']].apply(
    lambda x: pd.Series({
    'P-value < 0.1': (x.values < .1).mean(),
    'P-value < 0.05': (x.values < .05).mean(),
    'P-value < 0.01': (x.values < .01).mean(),
    'P-value < 0.001': (x.values < .001).mean(),
})).round(3).style.highlight_max().format('{:.3f}')
# Out:
# <style type="text/css">
# #T_5ddcb_row0_col0, #T_5ddcb_row0_col1, #T_5ddcb_row2_col0, #T_5ddcb_row2_col2, #T_5ddcb_row2_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5ddcb">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ddcb_level0_col0" class="col_heading level0 col0" >P-value < 0.1</th>
#       <th id="T_5ddcb_level0_col1" class="col_heading level0 col1" >P-value < 0.05</th>
#       <th id="T_5ddcb_level0_col2" class="col_heading level0 col2" >P-value < 0.01</th>
#       <th id="T_5ddcb_level0_col3" class="col_heading level0 col3" >P-value < 0.001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessing</th>
#       <th class="index_name level1" >Strategy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ddcb_level0_row0" class="row_heading level0 row0" rowspan="6">NoPreprocessing</th>
#       <th id="T_5ddcb_level1_row0" class="row_heading level1 row0" >Corr-50 </th>
#       <td id="T_5ddcb_row0_col0" class="data row0 col0" >0.998</td>
#       <td id="T_5ddcb_row0_col1" class="data row0 col1" >0.986</td>
#       <td id="T_5ddcb_row0_col2" class="data row0 col2" >0.869</td>
#       <td id="T_5ddcb_row0_col3" class="data row0 col3" >0.754</td>
#     </tr>
#     <tr>
#       <th id="T_5ddcb_level1_row1" class="row_heading level1 row1" >Identity </th>
#       <td id="T_5ddcb_row1_col0" class="data row1 col0" >0.879</td>
#       <td id="T_5ddcb_row1_col1" class="data row1 col1" >0.813</td>
#       <td id="T_5ddcb_row1_col2" class="data row1 col2" >0.732</td>
#       <td id="T_5ddcb_row1_col3" class="data row1 col3" >0.679</td>
#     </tr>
#     <tr>
#       <th id="T_5ddcb_level1_row2" class="row_heading level1 row2" >LGMRF </th>
#       <td id="T_5ddcb_row2_col0" class="data row2 col0" >0.998</td>
#       <td id="T_5ddcb_row2_col1" class="data row2 col1" >0.983</td>
#       <td id="T_5ddcb_row2_col2" class="data row2 col2" >0.876</td>
#       <td id="T_5ddcb_row2_col3" class="data row2 col3" >0.786</td>
#     </tr>
#     <tr>
#       <th id="T_5ddcb_level1_row3" class="row_heading level1 row3" >LGMRF uniform-weighting</th>
#       <td id="T_5ddcb_row3_col0" class="data row3 col0" >0.990</td>
#       <td id="T_5ddcb_row3_col1" class="data row3 col1" >0.973</td>
#       <td id="T_5ddcb_row3_col2" class="data row3 col2" >0.849</td>
#       <td id="T_5ddcb_row3_col3" class="data row3 col3" >0.759</td>
#     </tr>
#     <tr>
#       <th id="T_5ddcb_level1_row4" class="row_heading level1 row4" >Pairs-20 </th>
#       <td id="T_5ddcb_row4_col0" class="data row4 col0" >0.555</td>
#       <td id="T_5ddcb_row4_col1" class="data row4 col1" >0.455</td>
#       <td id="T_5ddcb_row4_col2" class="data row4 col2" >0.248</td>
#       <td id="T_5ddcb_row4_col3" class="data row4 col3" >0.087</td>
#     </tr>
#     <tr>
#       <th id="T_5ddcb_level1_row5" class="row_heading level1 row5" >Pairs-5 </th>
#       <td id="T_5ddcb_row5_col0" class="data row5 col0" >0.555</td>
#       <td id="T_5ddcb_row5_col1" class="data row5 col1" >0.438</td>
#       <td id="T_5ddcb_row5_col2" class="data row5 col2" >0.163</td>
#       <td id="T_5ddcb_row5_col3" class="data row5 col3" >0.020</td>
#     </tr>
#   </tbody>
# </table>

# %%
rolling_alpha_plots_df_melt[((rolling_alpha_plots_df_melt['Metric'] == 'p-value') &
                             (rolling_alpha_plots_df_melt['Preprocessing'] == 'Residuals'))].groupby(['Preprocessing', 'Strategy'])[['value']].apply(
    lambda x: pd.Series({
    'P-value < 0.1': (x.values < .1).mean(),
    'P-value < 0.05': (x.values < .05).mean(),
    'P-value < 0.01': (x.values < .01).mean(),
    'P-value < 0.001': (x.values < .001).mean(),
})).round(3).style.highlight_max().format('{:.3f}')
# Out:
# <style type="text/css">
# #T_9305d_row0_col0, #T_9305d_row2_col1, #T_9305d_row2_col2, #T_9305d_row2_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9305d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9305d_level0_col0" class="col_heading level0 col0" >P-value < 0.1</th>
#       <th id="T_9305d_level0_col1" class="col_heading level0 col1" >P-value < 0.05</th>
#       <th id="T_9305d_level0_col2" class="col_heading level0 col2" >P-value < 0.01</th>
#       <th id="T_9305d_level0_col3" class="col_heading level0 col3" >P-value < 0.001</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessing</th>
#       <th class="index_name level1" >Strategy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9305d_level0_row0" class="row_heading level0 row0" rowspan="6">Residuals</th>
#       <th id="T_9305d_level1_row0" class="row_heading level1 row0" >Corr-50 </th>
#       <td id="T_9305d_row0_col0" class="data row0 col0" >0.783</td>
#       <td id="T_9305d_row0_col1" class="data row0 col1" >0.710</td>
#       <td id="T_9305d_row0_col2" class="data row0 col2" >0.537</td>
#       <td id="T_9305d_row0_col3" class="data row0 col3" >0.265</td>
#     </tr>
#     <tr>
#       <th id="T_9305d_level1_row1" class="row_heading level1 row1" >Identity </th>
#       <td id="T_9305d_row1_col0" class="data row1 col0" >0.744</td>
#       <td id="T_9305d_row1_col1" class="data row1 col1" >0.689</td>
#       <td id="T_9305d_row1_col2" class="data row1 col2" >0.474</td>
#       <td id="T_9305d_row1_col3" class="data row1 col3" >0.238</td>
#     </tr>
#     <tr>
#       <th id="T_9305d_level1_row2" class="row_heading level1 row2" >LGMRF </th>
#       <td id="T_9305d_row2_col0" class="data row2 col0" >0.772</td>
#       <td id="T_9305d_row2_col1" class="data row2 col1" >0.730</td>
#       <td id="T_9305d_row2_col2" class="data row2 col2" >0.591</td>
#       <td id="T_9305d_row2_col3" class="data row2 col3" >0.307</td>
#     </tr>
#     <tr>
#       <th id="T_9305d_level1_row3" class="row_heading level1 row3" >LGMRF uniform-weighting</th>
#       <td id="T_9305d_row3_col0" class="data row3 col0" >0.776</td>
#       <td id="T_9305d_row3_col1" class="data row3 col1" >0.722</td>
#       <td id="T_9305d_row3_col2" class="data row3 col2" >0.587</td>
#       <td id="T_9305d_row3_col3" class="data row3 col3" >0.304</td>
#     </tr>
#     <tr>
#       <th id="T_9305d_level1_row4" class="row_heading level1 row4" >Pairs-20 </th>
#       <td id="T_9305d_row4_col0" class="data row4 col0" >0.426</td>
#       <td id="T_9305d_row4_col1" class="data row4 col1" >0.374</td>
#       <td id="T_9305d_row4_col2" class="data row4 col2" >0.228</td>
#       <td id="T_9305d_row4_col3" class="data row4 col3" >0.080</td>
#     </tr>
#     <tr>
#       <th id="T_9305d_level1_row5" class="row_heading level1 row5" >Pairs-5 </th>
#       <td id="T_9305d_row5_col0" class="data row5 col0" >0.168</td>
#       <td id="T_9305d_row5_col1" class="data row5 col1" >0.127</td>
#       <td id="T_9305d_row5_col2" class="data row5 col2" >0.037</td>
#       <td id="T_9305d_row5_col3" class="data row5 col3" >0.003</td>
#     </tr>
#   </tbody>
# </table>

# %%
with open("results/grid_backtester.pkl", "rb") as input_file:
    backtester = pickle.load(input_file)

# %%
L_lgmrf = backtester._configs['NoPreprocessing LGMRF']._split_backtesters[-1]._trader._L
((((np.diag(np.diag(L_lgmrf)) - L_lgmrf) > 0).sum(axis=0)).mean(), 
 (((np.diag(np.diag(L_lgmrf)) - L_lgmrf) > 0).sum(axis=0)).mean() / L_lgmrf.shape[1] * 100)

# %%
L_ltmrf = backtester._configs['NoPreprocessing LTMRF']._split_backtesters[-1]._trader._L
((((np.diag(np.diag(L_ltmrf)) - L_ltmrf) > 0).sum(axis=0)).mean(), 
 (((np.diag(np.diag(L_ltmrf)) - L_ltmrf) > 0).sum(axis=0)).mean() / L_ltmrf.shape[1] * 100)

# %%
L_lgmrf.shape[1]
