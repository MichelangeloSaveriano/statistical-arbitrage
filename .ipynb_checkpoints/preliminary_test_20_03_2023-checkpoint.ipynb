# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

from src.backtesting import *
from src.trading import *
from src.laplacian_estimators import *
from src.preprocessing import *

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Load Stocks Data

# %%
# SP500 Data
prices = pd.read_csv("./data/sp500_prices_long.csv", parse_dates=['Date'])
prices['month'] = prices['Date'].dt.month
prices['year'] = prices['Date'].dt.year
raw_monthly_prices = prices.groupby(['year', 'month']).last().reset_index()
raw_monthly_prices['year_month'] = raw_monthly_prices['year'].astype(str) + ('00' + raw_monthly_prices['month'].astype(str)).str[-2:]
raw_monthly_prices = raw_monthly_prices.set_index('year_month').drop(columns=['year', 'month', 'Date'])
monthly_prices = raw_monthly_prices.loc[:, raw_monthly_prices.isna().mean(axis=0) < .5]
monthly_log_returns = np.log(monthly_prices).diff().iloc[1:]
monthly_log_returns = np.exp(monthly_log_returns) - 1
monthly_log_returns.head()
# Out:
#              A  AAL  AAP      AAPL       ABC      ABMD       ABT  ACN  \
# year_month
# 199502     NaN  NaN  NaN -0.018981       NaN  0.555556  0.003533  NaN
# 199503     NaN  NaN  NaN -0.107596       NaN -0.171429  0.007043  NaN
# 199504     NaN  NaN  NaN  0.085107       NaN  0.206897  0.107499  NaN
# 199505     NaN  NaN  NaN  0.089615  0.028249 -0.028571  0.015873  NaN
# 199506     NaN  NaN  NaN  0.117294  0.002747  0.014706  0.012500  NaN
#
#                 ADBE       ADI  ...       WST        WY  WYNN       XEL  \
# year_month                      ...
# 199502      0.235421  0.168606  ... -0.037036  0.075907   NaN -0.021621
# 199503      0.385995  0.014925  ... -0.019232 -0.046012   NaN -0.027624
# 199504      0.176768  0.053921  ...  0.102896  0.080386   NaN  0.020997
# 199505     -0.107296  0.158139  ...  0.004465  0.054687   NaN  0.070621
# 199506      0.115385  0.092370  ... -0.004445  0.074074   NaN -0.026385
#
#                  XOM      XRAY  YUM  ZBH      ZBRA      ZION
# year_month
# 199502      0.034362 -0.049999  NaN  NaN -0.090625  0.059603
# 199503      0.043053  0.047373  NaN  NaN  0.127148 -0.048934
# 199504      0.043151  0.014389  NaN  NaN  0.118902  0.129139
# 199505      0.037924  0.021277  NaN  NaN -0.019073  0.061584
# 199506     -0.010507  0.002102  NaN  NaN  0.183333  0.112762
#
# [5 rows x 427 columns]

# %% [raw]
# # CRSP Data
# prices = pd.read_csv("./data/prices_CRSP.csv")
# prices['datadate'] = prices['datadate'].astype(str).str[:-2]
# prices = prices.rename(columns={'datadate': 'year_month'}).set_index('year_month')
# monthly_log_returns = np.log(prices).diff().iloc[1:]
# monthly_log_returns = np.exp(monthly_log_returns) - 1
# monthly_log_returns.head()

# %% [markdown]
# ## Load Factors Data

# %%
factors = pd.read_csv("./data/F-F_Research_Data_5_Factors_2x3.csv", skiprows=2)
factors = factors[factors['Date'].astype(str).str.strip().str.len() == 6]
factors = factors.set_index('Date')
factors = factors.astype(np.float64)
factors
# Out:
#         Mkt-RF   SMB   HML   RMW   CMA    RF
# Date
# 196307   -0.39 -0.41 -0.97  0.68 -1.18  0.27
# 196308    5.07 -0.80  1.80  0.36 -0.35  0.25
# 196309   -1.57 -0.52  0.13 -0.71  0.29  0.27
# 196310    2.53 -1.39 -0.10  2.80 -2.01  0.29
# 196311   -0.85 -0.88  1.75 -0.51  2.24  0.27
# ...        ...   ...   ...   ...   ...   ...
# 202205   -0.34 -0.06  8.41  1.44  3.98  0.03
# 202206   -8.43  1.30 -5.97  1.85 -4.70  0.06
# 202207    9.57  1.88 -4.10  0.68 -6.94  0.08
# 202208   -3.78  1.51  0.31 -4.80  1.31  0.19
# 202209   -9.36 -0.96  0.05 -1.40 -0.82  0.19
#
# [711 rows x 6 columns]

# %% [markdown]
# ## Marge Indexes

# %%
idx = monthly_log_returns.merge(factors, right_index=True, left_index=True).index
monthly_log_returns = monthly_log_returns.loc[idx]
factors = factors.loc[idx]

# %% [markdown]
# ## Remove Risk-free Returns

# %%
monthly_log_returns_rf = monthly_log_returns - factors[['RF']].values / 100
factors_rf = factors.drop(columns='RF')

# %% [markdown]
# # Backtest Strategies

# %%
# ?ResidualsPreprocessing

# %%
split_window_size = 24

config_backtesters = dict()

config_backtesters['NoPreprocessing Identity'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=SpreadsTradingRule(laplacian_estimator=LaplacianIdentityLaplacianEstimator()),
    split_window_size=split_window_size
)

config_backtesters['NoPreprocessing Corr-50'] = ConfigBacktester(
    preprocessor=NoPreprocessing(),
    trader=SpreadsTradingRule(laplacian_estimator=LaplacianCorrKLaplacianEstimator(k=50)),
    split_window_size=split_window_size
)

config_backtesters['NoPreprocessing Corr-50'] = ConfigBacktester(
    preprocessor=ResidualsPreprocessing(factors_rf),
    trader=SpreadsTradingRule(laplacian_estimator=LaplacianCorrKLaplacianEstimator(k=50)),
    split_window_size=split_window_size
)

# config_backtesters['NoPreprocessing LGMRF'] = ConfigBacktester(
#     preprocessor=NoPreprocessing(),
#     trader=SpreadsTradingRule(laplacian_estimator=LaplacianGraphLearningLaplacianEstimator()),
#     split_window_size=split_window_size
# )

backtester = GridBacktester(config_backtesters, verbose=True)

# %%
config_returns = backtester.backtest(monthly_log_returns)
config_returns
# Out:
#  50%|██████████████████████████████████████████                                          | 1/2 [00:00<00:00,  8.06it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-8a235dcb35f2> in <module>
# ----> 1 config_returns = backtester.backtest(monthly_log_returns)
#       2 config_returns
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\backtesting_folder\grid_config_backtester.py in backtest(self, returns)
#      16             items = tqdm(self._configs.items())
#      17
# ---> 18         return pd.DataFrame({
#      19             config_name: backtester.backtest(returns) for config_name, backtester in items
#      20         })
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\backtesting_folder\grid_config_backtester.py in <dictcomp>(.0)
#      17
#      18         return pd.DataFrame({
# ---> 19             config_name: backtester.backtest(returns) for config_name, backtester in items
#      20         })
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\backtesting_folder\configuration_backtester.py in backtest(self, returns)
#      37
#      38         executor = ThreadPoolExecutor()
# ---> 39         self._split_backtesters = list(
#      40             executor.map(lambda idx: SplitBacktester(preprocessor=copy.deepcopy(self._preprocessor),
#      41                                                      trader=copy.deepcopy(self._trader)).fit(returns.loc[idx]),
#
# ~\anaconda3\envs\datascience\lib\concurrent\futures\_base.py in result_iterator()
#     609                     # Careful not to keep a reference to the popped future
#     610                     if timeout is None:
# --> 611                         yield fs.pop().result()
#     612                     else:
#     613                         yield fs.pop().result(end_time - time.monotonic())
#
# ~\anaconda3\envs\datascience\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~\anaconda3\envs\datascience\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ~\anaconda3\envs\datascience\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\backtesting_folder\configuration_backtester.py in <lambda>(idx)
#      38         executor = ThreadPoolExecutor()
#      39         self._split_backtesters = list(
# ---> 40             executor.map(lambda idx: SplitBacktester(preprocessor=copy.deepcopy(self._preprocessor),
#      41                                                      trader=copy.deepcopy(self._trader)).fit(returns.loc[idx]),
#      42                          train_idx))
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\backtesting_folder\split_backtester.py in fit(self, train_returns)
#      13         train_returns = train_returns.loc[:, self._not_na_columns]
#      14
# ---> 15         preprocessed_train_returns = self._preprocessor.fit_transform(train_returns)
#      16         self._trader.fit(preprocessed_train_returns)
#      17         return self
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\preprocessing_folder\residuals_preprocessing.py in fit_transform(self, train)
#      33
#      34     def fit_transform(self, train):
# ---> 35         self.fit(train)
#      36         return self.transform(train)
#
# ~\OneDrive\Desktop\Statistical Arbitrage via Graph Laplacians\StatisticalArbitrage\src\preprocessing_folder\residuals_preprocessing.py in fit(self, train, test)
#      12         train_factors_merged = train.merge(self._factors, right_index=True, left_index=True,
#      13                                            suffixes=['', '_factor'])
# ---> 14         factors_data = train_factors_merged[self._factors.columns + '_factor']
#      15         train_data = train_factors_merged.drop(columns=self._factors.columns + '_factor')
#      16
#
# ~\anaconda3\envs\datascience\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\datascience\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\envs\datascience\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['RMW_factor', 'Mkt-RF_factor', 'SMB_factor', 'HML_factor'] not in index"

# %%
(1 + config_returns).cumprod().plot()
# Out:
# <AxesSubplot:>

# %%
config_returns.corr()
# Out:
#                           NoPreprocessing Identity  NoPreprocessing Corr-50
# NoPreprocessing Identity                  1.000000                 0.940768
# NoPreprocessing Corr-50                   0.940768                 1.000000

# %%
from tsxv.splitTrain import split_train

# %%
split_window_size = 24
split_train(monthly_log_returns_rf.index.values, numInputs=60,
            numOutputs=split_window_size + 1, numJumps=split_window_size)
# Out:
# ([array(['199502', '199503', '199504', '199505', '199506', '199507',
#          '199508', '199509', '199510', '199511', '199512', '199601',
#          '199602', '199603', '199604', '199605', '199606', '199607',
#          '199608', '199609', '199610', '199611', '199612', '199701',
#          '199702', '199703', '199704', '199705', '199706', '199707',
#          '199708', '199709', '199710', '199711', '199712', '199801',
#          '199802', '199803', '199804', '199805', '199806', '199807',
#          '199808', '199809', '199810', '199811', '199812', '199901',
#          '199902', '199903', '199904', '199905', '199906', '199907',
#          '199908', '199909', '199910', '199911', '199912', '200001'],
#         dtype=object),
#   array(['199702', '199703', '199704', '199705', '199706', '199707',
#          '199708', '199709', '199710', '199711', '199712', '199801',
#          '199802', '199803', '199804', '199805', '199806', '199807',
#          '199808', '199809', '199810', '199811', '199812', '199901',
#          '199902', '199903', '199904', '199905', '199906', '199907',
#          '199908', '199909', '199910', '199911', '199912', '200001',
#          '200002', '200003', '200004', '200005', '200006', '200007',
#          '200008', '200009', '200010', '200011', '200012', '200101',
#          '200102', '200103', '200104', '200105', '200106', '200107',
#          '200108', '200109', '200110', '200111', '200112', '200201'],
#         dtype=object),
#   array(['199902', '199903', '199904', '199905', '199906', '199907',
#          '199908', '199909', '199910', '199911', '199912', '200001',
#          '200002', '200003', '200004', '200005', '200006', '200007',
#          '200008', '200009', '200010', '200011', '200012', '200101',
#          '200102', '200103', '200104', '200105', '200106', '200107',
#          '200108', '200109', '200110', '200111', '200112', '200201',
#          '200202', '200203', '200204', '200205', '200206', '200207',
#          '200208', '200209', '200210', '200211', '200212', '200301',
#          '200302', '200303', '200304', '200305', '200306', '200307',
#          '200308', '200309', '200310', '200311', '200312', '200401'],
#         dtype=object),
#   array(['200102', '200103', '200104', '200105', '200106', '200107',
#          '200108', '200109', '200110', '200111', '200112', '200201',
#          '200202', '200203', '200204', '200205', '200206', '200207',
#          '200208', '200209', '200210', '200211', '200212', '200301',
#          '200302', '200303', '200304', '200305', '200306', '200307',
#          '200308', '200309', '200310', '200311', '200312', '200401',
#          '200402', '200403', '200404', '200405', '200406', '200407',
#          '200408', '200409', '200410', '200411', '200412', '200501',
#          '200502', '200503', '200504', '200505', '200506', '200507',
#          '200508', '200509', '200510', '200511', '200512', '200601'],
#         dtype=object),
#   array(['200302', '200303', '200304', '200305', '200306', '200307',
